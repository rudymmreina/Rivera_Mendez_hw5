# %%
# %pylab inline
import math
import matplotlib.pyplot as plt
import numpy as np
from numpy import pi
from scipy.fftpack import fft, fftfreq, fft2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
circulos = loadtxt("circulos.dat")
x = circulos[:,0]
y = circulos[:,1]
scatter(x,y,s=0.1)
xlim(-3,3)
ylim(-3,3)
print len(x)
print len(y)
# Out:
# 29010
# 29010

# %%
intervalo_x= round(max(x))-round(min(x))
n_points_x=300
h_x=intervalo_x/n_points_x


intervalo_y= round(max(y))-round(min(y))
n_points_y=300
h_y=intervalo_y/n_points_y

A=np.zeros((n_points_x,n_points_y))


for i in range((n_points_x-1)):
    for j in range((n_points_y-1)):
        index = where( (  (x<(-3+((i+1)*h_x) )) & (x>(-3+(i*h_x))) ) &  ( (y>(-3+(j*h_y))) & (y<(-3+((j+1)*h_y))) )    ) 
        A[i][j] = len(index[0])

# %%
plt.imshow(A,cmap="gray")
fft_a=np.fft.fft2(A)
spect=fft_a**2
back=fftpack.ifft2(fft_a)
Corr=fftpack.ifft2(spect)

# %%
plt.imshow(real(Corr))

# %%
n_points_x=1000

n_points_y=1000


C=np.zeros((n_points_x,n_points_y))


for i in range((n_points_x)):
    for j in range((n_points_y)):
        d=sqrt((200-i)**2+(300-j)**2)
        g=sqrt((500-i)**2+(400-j)**2)
        e=sqrt((400-i)**2+(400-j)**2)
        r=sqrt((300-i)**2+(500-j)**2)
        t=sqrt((300-i)**2+(700-j)**2)
        y=sqrt((200-i)**2+(600-j)**2)
        if  (((d)>200)&((d)<205)) or (((g)>200)&((g)<205)) or (((e)>200)&((e)<205)) or (((r)>200)&((r)<205)) or (((t)>200)&((t)<205)) or (((y)>200)&((y)<205)):
            C[i][j] = 1
        else:
            C[i][j] = 0
plt.imshow(C,cmap = cm.Greys_r)

# %%
fft_c=np.fft.fft2(C)
spect2=fft_c**2
back2=fftpack.ifft2(fft_c)
Corr2=fftpack.ifft2(spect2)
plt.imshow(real(Corr2))

# %%
def fourier_2d(imagen):
    im_fft=np.fft.fft2(imagen)
    im_fft[0,0]=0
    im_sfft=np.fft.fftshift(im_fft)
    im_sfft_mag=np.abs(im_sfft)
    im_spec_powr=im_sfft_mag**2
    return im_sfft_mag,im_spec_powr

# %%
cf=fourier_2d(C)[1]
plt.imshow(cf,cmap="gray")
plt.xlim(400,600)
plt.ylim(400,600)
# Out:
# (400, 600)
