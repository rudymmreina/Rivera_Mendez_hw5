# %%
import scikits.audiolab as audio
from scipy.fftpack import fft, fftfreq
from __future__ import division
# %pylab inline
# Out:
# /usr/local/lib/python2.7/dist-packages/scikits.audiolab-0.11.0-py2.7-linux-x86_64.egg/scikits/__init__.py:1: UserWarning: Module dap was already imported from None, but /usr/lib/python2.7/dist-packages is being added to sys.path
#   __import__('pkg_resources').declare_namespace(__name__)
# WARNING:
# Populating the interactive namespace from numpy and matplotlib
# pylab import has clobbered these variables: ['fft']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
input_signal, sampling_rate, enc = audio.wavread("prueba.wav")
time_array = arange(0, len(input_signal)/float(sampling_rate), 1/float(sampling_rate))
print len(time_array), len(input_signal)
# Out:
# 240000 240000

# %%
#plot(time_array[0:4000], input_signal[0:4000])
plot(time_array, input_signal)
xlabel("time(s)", fontsize=20)
ylabel("Amplitude", fontsize=20)

# %%
from scipy.fftpack import fft, fftfreq
fft_v=fft(input_signal)
#duracion en segundos
d=5
freq=fftfreq(len(input_signal),5/len(input_signal))
xlim(-1000,1000)
plot(freq,abs(fft_v))

# %%
whitef=2000*fft_v/(abs(fft_v))
whitespectrum=abs(whitef)**2
scatter(freq,abs(whitespectrum))

# %%
antiwhite=ifft(whitef)
plot(antiwhite)
output_file = audio.Sndfile("white.wav", 'w', audio.Format('wav'), 1, sampling_rate)
output_file.write_frames(real(antiwhite))
output_file.close()

# %%
freqn=np.fft.fftshift(freq)
for i in range(len(freqn)):
    if(freqn[i]==0):
        freqn[i]=0.1
hyp=1/(abs(freqn)**0.5)
whitefn=np.fft.fftshift(whitef)
pink=whitefn*hyp
pink_spectrum=abs(pink)**2
plot(freqn,abs(hyp))
#len(freqn[12001:24000])
#len(pink[12001:24000])
print abs(pink)
scatter(freqn,pink_spectrum)
# Out:
# [ 12.90994449  12.90999828  12.91005207 ...,  12.91010586  12.91005207
#   12.90999828]

# %%
antipink=10*ifft(pink)
plot(antipink)
output_file = audio.Sndfile("pink.wav", 'w', audio.Format('wav'), 1, sampling_rate)
output_file.write_frames(real(antipink))
output_file.close()
